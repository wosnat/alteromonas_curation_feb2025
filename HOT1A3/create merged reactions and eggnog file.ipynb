# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
import os

# %%
os.listdir('data')
# Out:
# ['eggnog_data_20250227_180812.xlsx',
#  'hot1a3_genome.rast.mdl',
#  'hot1a3_genome.rast.mdl.gf_lb',
#  'hot1a3_genome.rast.mdl.gf_min_glc',
#  'zip files']

# %%
eggnog_excel_fpath = os.path.join('data', 'HOT1A3_eggnog_data_20250227_180812.xlsx')
initial_model_fpath = os.path.join('data', 'hot1a3_genome.rast.mdl', 'hot1a3_genome.rast.mdl.xls')
final_model_glc_minimal_fpath = os.path.join('data', 'hot1a3_genome.rast.mdl.gf_min_glc', 'hot1a3_genome.rast.mdl.xls')
final_model_LB_fpath = os.path.join('data', 'hot1a3_genome.rast.mdl.gf_lb', 'hot1a3_genome.rast.mdl.xls')

# %%
df_eggnog = pd.read_excel(eggnog_excel_fpath)

# %%
df_eggnog = df_eggnog.dropna(subset='query', ).copy()

# %%
df_eggnog.KBase_rxns_draft
# Out:
# 0                    []
# 1                    []
# 2       ["rxn05296_c0"]
# 3       ["rxn05294_c0"]
# 4                    []
#              ...
# 3834                 []
# 3835                 []
# 3836                 []
# 3837                 []
# 3838                 []
# Name: KBase_rxns_draft, Length: 3839, dtype: object

# %%
import ast
def _liststr_to_str(x):
    if x is np.NaN:
        return ''
    #print(x)
    x1 = ast.literal_eval(x)
    return ','.join(x1)
df_eggnog['KBase_rxns_draft'] = df_eggnog.KBase_rxns_draft.apply(_liststr_to_str)

# %%
def find_in_eggnog_df(df_merge, df_eggnog, colname, kbase_colname, haseggnog_str):
    colname_explode = f'{colname}_explode' 
    df_eggnog[colname_explode] = df_eggnog[colname].str.split(',')
    df_eggnog_explode = df_eggnog.explode(column=colname_explode, ignore_index=True) 
    df_eggnog_explode_nodup = df_eggnog_explode.dropna(subset=colname_explode).drop_duplicates(subset=colname_explode)
    df_merge1 = pd.merge(df_merge, df_eggnog_explode_nodup, left_on=kbase_colname, right_on=colname_explode, how='left', )
    df_merge1['Has_Eggnog'] = 'No'
    df_merge1.loc[~df_merge1[colname_explode].isna(), 'Has_Eggnog'] = haseggnog_str
    #display(df_eggnog_explode_nodup[colname_explode].value_counts())
    #display(df_merge1[['Has_Eggnog','is_Gap_Fill', ]].value_counts().reset_index().pivot(index='Has_Eggnog', columns='is_Gap_Fill'))
    return df_merge1

# %%
def look_for_eggnog_on_onmatched_reactions(df_merge_matched, df_merge, df_eggnog, colname, kbase_colname, haseggnog_str ):
    rxn_without_match = df_merge_matched.loc[df_merge_matched.Has_Eggnog.isin(['No']), 'ms id']
    df_merge_no_eggnog = df_merge.loc[df_merge['ms id'].isin(rxn_without_match)]
    df_merge_matched_new = find_in_eggnog_df(df_merge_no_eggnog, df_eggnog, colname, kbase_colname, haseggnog_str)
    df_merge_matched_has_eggnog = df_merge_matched.loc[~df_merge_matched['ms id'].isin(rxn_without_match)]
    return df_merge_matched_has_eggnog, df_merge_matched_new

# %%
def compare_2_models(initial_model_fpath, final_model_fpath, df_eggnog):
    df_init = pd.read_excel(initial_model_fpath, sheet_name='ModelReactions')
    df_final = pd.read_excel(final_model_fpath, sheet_name='ModelReactions')    
    df_merge = pd.merge(df_final, df_init[['id', 'direction']], on='id', how='left', suffixes=['_final', '_init'])
    df_merge['is_Gap_Fill'] = 'No'
    df_merge.loc[df_merge.direction_init != df_merge.direction_final, 'is_Gap_Fill'] = 'Direction'
    df_merge.loc[df_merge.direction_init.isna(), 'is_Gap_Fill'] = 'Yes'
    df_merge_matched_1 = find_in_eggnog_df(df_merge, df_eggnog, 'Manual_ModelSeed_rxn_ID', 'ms id', 'ModelSeed RXN')
    df_merge_matched_has_eggnog_1, df_merge_matched_2 = look_for_eggnog_on_onmatched_reactions(
        df_merge_matched_1, df_merge, df_eggnog, 'KBase_rxns_draft', 'id', 'ModelSeed RXN')
    df_merge_matched_has_eggnog_2, df_merge_matched_3 = look_for_eggnog_on_onmatched_reactions(
        df_merge_matched_2, df_merge, df_eggnog, 'KEGG_Reaction', 'kegg id', 'KEGG RXN')

    df_merge_final = pd.concat([
        df_merge_matched_has_eggnog_1,
        df_merge_matched_has_eggnog_2,
        df_merge_matched_3,
    ], ignore_index=True)
    
    first_cols = ['id','is_Gap_Fill','Has_Eggnog']
    cols = first_cols + [c for c in df_merge_final.columns if c not in first_cols]
    display(df_merge_final[['Has_Eggnog','is_Gap_Fill', ]].value_counts().reset_index().pivot(index='Has_Eggnog', columns='is_Gap_Fill').fillna(0))
    
    return df_merge_final[cols]

# %%
df_merge_glc_min =  compare_2_models(initial_model_fpath, final_model_glc_minimal_fpath, df_eggnog)
df_merge_glc_min.to_excel('HOT1A3_GF_glc_min_reactions_with_eggnog.xlsx', index=False)
# Out:
#                 count
# is_Gap_Fill        No   Yes
# Has_Eggnog
# KEGG RXN          1.0   0.0
# ModelSeed RXN  1210.0   6.0
# No               31.0  26.0

# %%
df_merge_lb =  compare_2_models(initial_model_fpath, final_model_LB_fpath, df_eggnog)
df_merge_lb.to_excel('HOT1A3_GF_glc_min_reactions_with_eggnog.xlsx', index=False)
# Out:
#                 count
# is_Gap_Fill        No   Yes
# Has_Eggnog
# KEGG RXN          1.0   0.0
# ModelSeed RXN  1210.0   6.0
# No               31.0  24.0

# %%
df_merge_lb_shared_mask = df_merge_lb['ms id'].isin(df_merge_glc_min['ms id'])

df_merge_lb_shared = df_merge_lb.loc[df_merge_lb_shared_mask]
df_merge_lb_unique = df_merge_lb.loc[~df_merge_lb_shared_mask]

# %%
df_merged_lb_glc_share = pd.merge(df_merge_glc_min, df_merge_lb_shared[['ms id', 'is_Gap_Fill']], on='ms id', how='left', suffixes=['_glc_min', '_LB'])

# %%
df_merged_lb_glc_share['is_Gap_Fill_LB'] = df_merged_lb_glc_share['is_Gap_Fill_LB'].fillna('N/A')

# %%
df_merge_lb_unique =df_merge_lb_unique.rename(columns={'is_Gap_Fill' : 'is_Gap_Fill_LB'})
df_merge_lb_unique['is_Gap_Fill_glc_min'] = 'N/A'

# %%
first_cols = ['id','is_Gap_Fill_glc_min', 'is_Gap_Fill_LB', 'Has_Eggnog']
df_merged_lb_glc_final = pd.concat([df_merged_lb_glc_share, df_merge_lb_unique])
cols = first_cols + [c for c in df_merged_lb_glc_final.columns if c not in first_cols]
df_merged_lb_glc_final =  df_merged_lb_glc_final[cols]

# %%
df_merged_lb_glc_final.to_excel('HOT1A3_reactions_gapfill_LB_MIN_GLC_with_eggnog.xlsx')

# %%
df_merged_lb_glc_final[['is_Gap_Fill_glc_min', 'is_Gap_Fill_LB', 'Has_Eggnog']].value_counts(dropna=False).reset_index().pivot(
    index='Has_Eggnog', columns=['is_Gap_Fill_glc_min', 'is_Gap_Fill_LB'], ).fillna(0)
# Out:
#                       count
# is_Gap_Fill_glc_min      No   Yes         N/A
# is_Gap_Fill_LB           No   Yes   N/A   Yes
# Has_Eggnog
# KEGG RXN                1.0   0.0   0.0   0.0
# ModelSeed RXN        1210.0   5.0   1.0   1.0
# No                     31.0  14.0  12.0  10.0

# %%
df_merged_lb_glc_final[['is_Gap_Fill_glc_min', 'is_Gap_Fill_LB', ]].value_counts(dropna=False).reset_index().pivot(
    index='is_Gap_Fill_LB', columns=['is_Gap_Fill_glc_min',], ).fillna(0)
# Out:
#                     count
# is_Gap_Fill_glc_min   N/A      No   Yes
# is_Gap_Fill_LB
# N/A                   0.0     0.0  13.0
# No                    0.0  1242.0   0.0
# Yes                  11.0     0.0  19.0

# %%
df_merge_glc_min.is_Gap_Fill.value_counts(dropna=False), df_merged_lb_glc_final.is_Gap_Fill_glc_min.value_counts(dropna=False)
# Out:
# (is_Gap_Fill
#  No     1242
#  Yes      32
#  Name: count, dtype: int64,
#  is_Gap_Fill_glc_min
#  No     1242
#  Yes      32
#  N/A      11
#  Name: count, dtype: int64)

# %%
df_merge_lb.is_Gap_Fill.value_counts(dropna=False), df_merged_lb_glc_final.is_Gap_Fill_LB.value_counts(dropna=False)
# Out:
# (is_Gap_Fill
#  No     1242
#  Yes      30
#  Name: count, dtype: int64,
#  is_Gap_Fill_LB
#  No     1242
#  Yes      30
#  N/A      13
#  Name: count, dtype: int64)

# %%
df_merged_lb_glc_final['is_Gap_Fill_glc_min'].value_counts(dropna=False)
# Out:
# is_Gap_Fill_glc_min
# No     1242
# Yes      32
# N/A      11
# Name: count, dtype: int64

# %%
pd.merge(df_merge_lb[['ms id', 'is_Gap_Fill']], df_merge_glc_min[['ms id', 'is_Gap_Fill']], 
         on='ms id', how='outer', suffixes=['_glc_min', '_LB'])[['is_Gap_Fill_glc_min', 'is_Gap_Fill_LB',]].value_counts(dropna=False)
# Out:
# is_Gap_Fill_glc_min  is_Gap_Fill_LB
# No                   No                1242
# Yes                  Yes                 19
# NaN                  Yes                 13
# Yes                  NaN                 11
# Name: count, dtype: int64

# %%
df_merged_lb_glc_final['source'] = (df_merged_lb_glc_final.is_Gap_Fill_glc_min + ',' + df_merged_lb_glc_final.is_Gap_Fill_LB).map({
    'No,No' : 'Orig', 'Yes,Yes' : 'GF (Both)', 'Yes,N/A' : 'GF (GLC)', 'N/A,Yes' : 'GF (LB)',
})

# %%
df_merged_lb_glc_final_explode = df_merged_lb_glc_final.copy()
df_merged_lb_glc_final_explode['kegg pathway'] = df_merged_lb_glc_final_explode['kegg pathways'].str.split('|')
df_merged_lb_glc_final_explode = df_merged_lb_glc_final_explode.explode('kegg pathway')

# %%
df_merged_lb_glc_final_explode['kegg pathway'].unique()
# Out:
# array(['Folate biosynthesis', 'Glutathione metabolism',
#        'Valine, leucine and isoleucine degradation',
#        'Cysteine and methionine metabolism', 'Sulfur metabolism',
#        'Pyrimidine metabolism', 'Peptidoglycan biosynthesis',
#        'Glycolysis / Gluconeogenesis', 'Citrate cycle (TCA cycle)',
#        'Pyruvate metabolism',
#        'Carbon fixation in photosynthetic organisms',
#        'Fructose and mannose metabolism',
#        'Amino sugar and nucleotide sugar metabolism',
#        'Streptomycin biosynthesis', 'Polyketide sugar unit biosynthesis',
#        'Fatty acid elongation', 'Fatty acid degradation',
#        'Vitamin B6 metabolism', 'Arginine and proline metabolism',
#        'Glycine, serine and threonine metabolism', 'Purine metabolism',
#        'Alanine, aspartate and glutamate metabolism',
#        'Pantothenate and CoA biosynthesis',
#        'Pentose and glucuronate interconversions',
#        'Ascorbate and aldarate metabolism',
#        'Starch and sucrose metabolism', nan, 'Galactose metabolism',
#        'beta-Alanine metabolism', 'Inositol phosphate metabolism',
#        'Propanoate metabolism', 'Histidine metabolism',
#        'Porphyrin and chlorophyll metabolism', 'Fatty acid biosynthesis',
#        'Riboflavin metabolism', 'Phenylalanine metabolism',
#        'Styrene degradation', 'Nicotinate and nicotinamide metabolism',
#        'Methane metabolism', 'Thiamine metabolism',
#        'One carbon pool by folate',
#        'Phenylalanine, tyrosine and tryptophan biosynthesis',
#        'Benzoxazinoid biosynthesis', 'Lipopolysaccharide biosynthesis',
#        'Lysine biosynthesis', 'Tryptophan metabolism',
#        'Nitrogen metabolism',
#        'Valine, leucine and isoleucine biosynthesis',
#        'Novobiocin biosynthesis', 'Taurine and hypotaurine metabolism',
#        'Carbon fixation pathways in prokaryotes', 'Lysine degradation',
#        'Butanoate metabolism', 'Cyanoamino acid metabolism',
#        'Glyoxylate and dicarboxylate metabolism', 'Tyrosine metabolism',
#        'Biosynthesis of vancomycin group antibiotics',
#        'Terpenoid backbone biosynthesis',
#        'Synthesis and degradation of ketone bodies',
#        'Benzoate degradation', 'Glycerophospholipid metabolism',
#        'Aminobenzoate degradation', 'Pentose phosphate pathway',
#        'Glucosinolate biosynthesis', 'D-Alanine metabolism',
#        'D-Glutamine and D-glutamate metabolism', 'Biotin metabolism',
#        'Ubiquinone and other terpenoid-quinone biosynthesis',
#        'Isoquinoline alkaloid biosynthesis',
#        'C5-Branched dibasic acid metabolism', 'Caprolactam degradation',
#        'Geraniol degradation', 'Tetracycline biosynthesis',
#        'Glycerolipid metabolism', 'Butirosin and neomycin biosynthesis',
#        'Atrazine degradation',
#        'Tropane, piperidine and pyridine alkaloid biosynthesis',
#        'Biosynthesis of siderophore group nonribosomal peptides',
#        'Dioxin degradation', 'Xylene degradation',
#        'Steroid hormone biosynthesis',
#        'Biosynthesis of unsaturated fatty acids'], dtype=object)

# %%
df_merged_lb_glc_final_explode = df_merged_lb_glc_final_explode.reset_index(drop=True)

# %%
sns.catplot(
    data=df_merged_lb_glc_final_explode,
    col='source', y='kegg pathway', kind='count',
    sharex=False, 
    height=10, aspect=0.5,
    hue='kegg pathway', legend=False,
).set_titles(col_template='{col_name}')

# %%
interesting_keggs = df_merged_lb_glc_final_explode.loc[~df_merged_lb_glc_final_explode.source.isin(['Orig']), 'kegg pathway']
sns.catplot(
    data=df_merged_lb_glc_final_explode.loc[df_merged_lb_glc_final_explode['kegg pathway'].isin(interesting_keggs)],
    col='source', y='kegg pathway', kind='count',
    sharex=False, 
    #height=10, 
    aspect=0.5,
    hue='kegg pathway', legend=False,
).set_titles(col_template='{col_name}')
plt.suptitle('HOT1A3 Gapfilling', y=1.03)
# Out:
# Text(0.5, 1.03, 'HOT1A3 Gapfilling')

# %% [markdown]
# # exploration

# %%
df_init = pd.read_excel(initial_model_fpath, sheet_name='ModelReactions')
df_final = pd.read_excel(final_model_fpath, sheet_name='ModelReactions')

# %%
df_merge = pd.merge(df_final, df_init, on='id', how='outer', suffixes=['_final', '_init'])

# %%
# gap fill reactions

# %%
df_merge.loc[df_merge.direction_init.isna()]
# Out:
#               id direction_final compartment_final gpr_final  \
# 767  rxn03408_c0               >           Cytosol   Unknown
# 768  rxn00359_c0               <           Cytosol   Unknown
# 769  rxn12008_c0               <           Cytosol   Unknown
# 770  rxn08333_c0               >           Cytosol   Unknown
# 771  rxn02898_c0               >           Cytosol   Unknown
# ..           ...             ...               ...       ...
# 949  rxn10421_c0               >           Cytosol   Unknown
# 950  rxn05645_c0               >           Cytosol   Unknown
# 951  rxn01792_c0               >           Cytosol   Unknown
# 952  rxn01396_c0               >           Cytosol   Unknown
# 953  rxn05255_c0               >           Cytosol   Unknown
#
#                                             name_final enzyme_final  \
# 767  UDP-N-acetyl-D-glucosamine:undecaprenyl-diphos...          NaN
# 768          3'-phosphoadenylyl-sulfate sulfohydrolase      3.6.2.2
# 769                                             R05611          NaN
# 770   1,4-dihydroxy-2-naphthoate octaprenyltransferase          NaN
# 771  O-Succinylbenzoyl-CoA 1,4-dihydroxy-2-naphthoa...          NaN
# ..                                                 ...          ...
# 949  4-Aminobenzoate mitochondrial transport via sy...          NaN
# 950         riboflavin transport in via proton symport          NaN
# 951                        Pantothenate amidohydrolase     3.5.1.22
# 952               ATP:pyridoxine 5'-phosphotransferase          NaN
# 953                folate transport via proton simport          NaN
#
#      deltag_final  reference_final  \
# 767         -1.70              NaN
# 768        -30.34              NaN
# 769         22.53              NaN
# 770         10.17              NaN
# 771        -14.27              NaN
# ..            ...              ...
# 949          0.00              NaN
# 950          0.00              NaN
# 951         -0.46              NaN
# 952        -14.03              NaN
# 953          0.00              NaN
#
#                                         equation_final  \
# 767  (1)  cpd00037[c0] + (1)  cpd03494[c0] -> (1)  ...
# 768  (1)  cpd00001[c0] + (1)  cpd00044[c0] <- (1)  ...
# 769  (1)  cpd00012[c0] + (1)  cpd00067[c0] + (1)  c...
# 770  (1)  cpd02295[c0] + (1)  cpd02557[c0] -> (1)  ...
# 771  (1)  cpd02021[c0] -> (1)  cpd00010[c0] + (1)  ...
# ..                                                 ...
# 949  (1)  cpd00067[e0] + (1)  cpd00443[e0] -> (1)  ...
# 950  (1)  cpd00067[e0] + (1)  cpd00220[e0] -> (1)  ...
# 951  (1)  cpd00001[c0] + (1)  cpd00644[c0] -> (1)  ...
# 952  (1)  cpd00002[c0] + (1)  cpd00263[c0] -> (1)  ...
# 953  (1)  cpd00067[e0] + (1)  cpd00393[e0] -> (1)  ...
#
#                                       definition_final  ... enzyme_init  \
# 767  (1)  UDP-N-acetylglucosamine [c0][c0] + (1)  U...  ...         NaN
# 768  (1)  H2O [c0][c0] + (1)  3-phosphoadenylylsulf...  ...         NaN
# 769  (1)  PPi [c0][c0] + (1)  H+ [c0][c0] + (1)  Fa...  ...         NaN
# 770  (1)  1-4-Dihydroxy-2-naphthoate [c0][c0] + (1)...  ...         NaN
# 771  (1)  Succinylbenzoyl-CoA [c0][c0] -> (1)  CoA ...  ...         NaN
# ..                                                 ...  ...         ...
# 949  (1)  H+ [e0][e0] + (1)  ABEE [e0][e0] -> (1)  ...  ...         NaN
# 950  (1)  H+ [e0][e0] + (1)  Riboflavin [e0][e0] ->...  ...         NaN
# 951  (1)  H2O [c0][c0] + (1)  PAN [c0][c0] -> (1)  ...  ...         NaN
# 952  (1)  ATP [c0][c0] + (1)  Pyridoxol [c0][c0] ->...  ...         NaN
# 953  (1)  H+ [e0][e0] + (1)  Folate [e0][e0] -> (1)...  ...         NaN
#
#     deltag_init reference_init equation_init definition_init ms id_init  \
# 767         NaN            NaN           NaN             NaN        NaN
# 768         NaN            NaN           NaN             NaN        NaN
# 769         NaN            NaN           NaN             NaN        NaN
# 770         NaN            NaN           NaN             NaN        NaN
# 771         NaN            NaN           NaN             NaN        NaN
# ..          ...            ...           ...             ...        ...
# 949         NaN            NaN           NaN             NaN        NaN
# 950         NaN            NaN           NaN             NaN        NaN
# 951         NaN            NaN           NaN             NaN        NaN
# 952         NaN            NaN           NaN             NaN        NaN
# 953         NaN            NaN           NaN             NaN        NaN
#
#     bigg id_init kegg id_init kegg pathways_init metacyc pathways_init
# 767          NaN          NaN                NaN                   NaN
# 768          NaN          NaN                NaN                   NaN
# 769          NaN          NaN                NaN                   NaN
# 770          NaN          NaN                NaN                   NaN
# 771          NaN          NaN                NaN                   NaN
# ..           ...          ...                ...                   ...
# 949          NaN          NaN                NaN                   NaN
# 950          NaN          NaN                NaN                   NaN
# 951          NaN          NaN                NaN                   NaN
# 952          NaN          NaN                NaN                   NaN
# 953          NaN          NaN                NaN                   NaN
#
# [187 rows x 29 columns]

# %%
# removed reactions
df_merge.loc[df_merge.direction_final.isna()]
# Out:
# Empty DataFrame
# Columns: [id, direction_final, compartment_final, gpr_final, name_final, enzyme_final, deltag_final, reference_final, equation_final, definition_final, ms id_final, bigg id_final, kegg id_final, kegg pathways_final, metacyc pathways_final, direction_init, compartment_init, gpr_init, name_init, enzyme_init, deltag_init, reference_init, equation_init, definition_init, ms id_init, bigg id_init, kegg id_init, kegg pathways_init, metacyc pathways_init]
# Index: []
#
# [0 rows x 29 columns]

# %%
# column changes
tmp_df_merge =df_merge.loc[~df_merge.direction_init.isna()].copy()
tmp_df_merge = tmp_df_merge.fillna('NA')
for c in df_init.columns:
    if c == 'id':
        continue
    changed_values = tmp_df_merge.loc[tmp_df_merge[f'{c}_init'] != tmp_df_merge[f'{c}_final']]
    print(c, changed_values.shape[0])
# Out:
# direction 0
# compartment 0
# gpr 72
# name 0
# enzyme 0
# deltag 0
# reference 0
# equation 0
# definition 0
# ms id 0
# bigg id 0
# kegg id 0
# kegg pathways 0
# metacyc pathways 0

# %%
c='gpr'
changed_values = tmp_df_merge.loc[tmp_df_merge[f'{c}_init'] != tmp_df_merge[f'{c}_final']]
changed_values[[f'{c}_init',f'{c}_final']]
# Out:
#                                               gpr_init  \
# 2                            (1933_gene and 1934_gene)
# 20   (1352_gene or 2496_gene or 3042_gene or 967_gene)
# 21                  (684_gene or 685_gene or 686_gene)
# 30   (1866_gene and 1865_gene and 1868_gene and 186...
# 66             (1607_gene or (1247_gene or 1682_gene))
# ..                                                 ...
# 694                          (3503_gene and 3504_gene)
# 695  (2050_gene and 2054_gene and 643_gene and 2052...
# 696                          (3503_gene and 3504_gene)
# 698            (4027_gene and 4028_gene and 4028_gene)
# 732                           (259_gene and 2566_gene)
#
#                                              gpr_final
# 2                            (1934_gene and 1933_gene)
# 20   (2496_gene or 3042_gene or 1352_gene or 967_gene)
# 21                  (686_gene or 685_gene or 684_gene)
# 30   (1867_gene and 1865_gene and 1866_gene and 186...
# 66             (1607_gene or (1682_gene or 1247_gene))
# ..                                                 ...
# 694                          (3504_gene and 3503_gene)
# 695  (2052_gene and 2054_gene and 2055_gene and 643...
# 696                          (3504_gene and 3503_gene)
# 698            (4028_gene and 4027_gene and 4028_gene)
# 732                           (2566_gene and 259_gene)
#
# [72 rows x 2 columns]

# %%
import ast
df_eggnog.KBase_rxns_draft.apply(ast.literal_eval)
# Out:
# 0       [rxn05294_c0]
# 1       [rxn05294_c0]
# 2                  []
# 3       [rxn05294_c0]
# 4                  []
#             ...
# 3924               []
# 3925               []
# 3926               []
# 3927               []
# 3928               []
# Name: KBase_rxns_draft, Length: 3929, dtype: object
